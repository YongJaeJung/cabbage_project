# %%
import pandas as pd

df = pd.read_csv('./nongsan_data/public_data/train_AT_TSALET_ALL/AT_TSALET_ALL_202009.csv',encoding='utf-8')
df = df.rename(columns={'SALEDATE':'경락 일자',
'WHSAL_NM': '도매시장',
'CMP_NM': '법인',
'PUM_NM': '품목',
'KIND_NM': '품종',
'DAN_NM': '단위',
'POJ_NM': '포장',
'SIZE_NM': '크기',
'LV_NM': '등급',
'SAN_NM': '산지',
'DANQ': '단위중량',
'QTY': '물량',
'COST': '단가',
'TOT_QTY': '총물량',
'TOT_AMT': '총금액'})
df = df[df['품목']=='배추']

# %%
# 배추 전국에서 다함...?
df['산지'].unique()
# Out:
# array(['전라남도 해남군', '서울 송파구', '강원 평창군', '강원 태백시', '강원도 평창군', '강원 강릉시',
#        '광주 서구', '서울특별시', '대전 유성구', '강원도 정선군', '경기 의왕시', '부산 사상구',
#        '경상남도 합천군', '경기도 여주군', '충남 당진군', '경기 하남시', '충북 제천시', '전남 나주시',
#        '충남 예산군', '강원 홍천군', '경기도 양평군', '경북 고령군', '강원 춘천시', '강원 인제군',
#        '경기 양평군', '광주광역시', '경기 이천시', '경기 여주군', '부산 해운대구', '경남 진해시',
#        '경남 밀양시', '경남 합천군', '인천광역시 계양구', '강원도 태백시', '강원도 강릉시', '강원 원주시',
#        '경기도 광명시', '서울특별시 송파구', '강원도 삼척시', '경상북도 김천시', '경상북도 군위군',
#        '경상북도 영양군', '경상남도 거창군', '광주 광산구', '전남 순천시', '광주 북구', '경북 칠곡군',
#        '대구 중구', '충남 보령시', '전북 익산시', nan, '강원도 홍천군', '대구광역시', '충청남도 공주시',
#        '대전광역시', '경기도 이천시', '경기도 포천시', '경기도 안성시', '경기도 용인시', '충북 음성군',
#        '전라북도 무주군', '울산 남구', '경상북도 포항시', '부산 중구', '서울 중구', '경기도', '경상북도',
#        '경북 구미시', '경남 창원시', '경상북도 칠곡군', '대구 북구', '경기도 고양시', '인천광역시',
#        '경상남도 창녕군', '경상남도 남해군', '경기 구리시', '경기 남양주시', '경기 부천시 소사구',
#        '경기 안성시', '인천 남동구', '경기 수원시 권선구', '전라남도', '전북 완주군', '경북 영양군',
# ...

# %%
df['경락 일자'] = pd.to_datetime(df['경락 일자'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37020 entries, 1193 to 3453414
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   경락 일자   37020 non-null  datetime64[ns]
#  1   도매시장    37020 non-null  object
#  2   법인      37020 non-null  object
#  3   품목      37020 non-null  object
#  4   품종      37020 non-null  object
#  5   단위      37020 non-null  object
#  6   포장      37020 non-null  object
#  7   크기      36845 non-null  object
#  8   등급      37020 non-null  object
#  9   산지      36536 non-null  object
#  10  단위중량    37020 non-null  float64
#  11  물량      37020 non-null  int64
#  12  단가      37020 non-null  int64
#  13  총물량     37020 non-null  float64
#  14  총금액     37020 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(9)
# memory usage: 4.5+ MB

# %%
df
# Out:
#              경락 일자    도매시장       법인  품목     품종  단위   포장   크기 등급        산지  \
# 1193    2020-09-01  광주서부도매  농협광주(공)  배추   기타배추  kg  그물망    .  특  전라남도 해남군
# 1194    2020-09-01  광주서부도매  농협광주(공)  배추    쌈배추  kg   상자  22개  특    서울 송파구
# 1195    2020-09-01  광주서부도매  농협광주(공)  배추    쌈배추  kg    .    .  상    강원 평창군
# 1196    2020-09-01  광주서부도매  농협광주(공)  배추    쌈배추  kg    .    .  상    강원 평창군
# 1197    2020-09-01  광주서부도매  농협광주(공)  배추    쌈배추  kg    .    .  상    강원 평창군
# ...            ...     ...      ...  ..    ...  ..  ...  ... ..       ...
# 3452876 2020-09-28  인천구월도매    인천농산물  배추  고냉지배추  kg  그물망    .  상   강원도 정선군
# 3452877 2020-09-28  인천구월도매    인천농산물  배추  고냉지배추  kg  그물망    .  상   강원도 정선군
# 3452878 2020-09-28  인천구월도매    인천농산물  배추  고냉지배추  kg  그물망    .  상   강원도 정선군
# 3452879 2020-09-28  인천구월도매    인천농산물  배추  고냉지배추  kg  그물망    .  상   강원도 정선군
# 3453414 2020-09-28  인천구월도매    인천농산물  배추   기타배추  kg   상자    .  특   강원도 횡성군
#
#          단위중량   물량     단가     총물량      총금액
# ...
